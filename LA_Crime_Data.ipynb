# %%
# Install Libraries
# !pip install kagglehub
# !pip install kaggle
# !pip install pandas

# %%
# Import Libraries
import kagglehub
import os
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# Download latest version
path = kagglehub.dataset_download("sumaiaparveenshupti/los-angeles-crime-data-20102020")
print("Path to dataset files:", path)
# Out:
# ...
# Path to dataset files: C:\Users\odiss\.cache\kagglehub\datasets\sumaiaparveenshupti\los-angeles-crime-data-20102020\versions\3

# %%
# List all files in the specified directory and store the file names in the `files` list
files = [f for f in os.listdir(path) if os.path.isfile(os.path.join(path, f))]
print("Files in directory:", files)
# Out:
# Files in directory: ['Crime_Data_from_2010_to_2019.csv', 'Crime_Data_from_2020_to_Present.csv']

# %%
# Load the first CSV file into a DataFrame
la_crime_data_2010_to_2019 = pd.read_csv(os.path.join(path, files[0]))
la_crime_data_2010_to_2019
# Out:
#              DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 0          1307355  02/20/2010 12:00:00 AM  02/20/2010 12:00:00 AM      1350
# 1         11401303  09/13/2010 12:00:00 AM  09/12/2010 12:00:00 AM        45
# 2         70309629  08/09/2010 12:00:00 AM  08/09/2010 12:00:00 AM      1515
# 3         90631215  01/05/2010 12:00:00 AM  01/05/2010 12:00:00 AM       150
# 4        100100501  01/03/2010 12:00:00 AM  01/02/2010 12:00:00 AM      2100
# ...            ...                     ...                     ...       ...
# 2117584  190608903  03/28/2019 12:00:00 AM  03/28/2019 12:00:00 AM       400
# 2117585  190715222  08/15/2019 12:00:00 AM  08/14/2019 12:00:00 AM      1810
# 2117586  192004409  01/06/2019 12:00:00 AM  01/06/2019 12:00:00 AM      2100
# 2117587  191716777  10/17/2019 12:00:00 AM  10/16/2019 12:00:00 AM      1800
# 2117588  190805435  02/01/2019 12:00:00 AM  02/01/2019 12:00:00 AM      1615
#
# ...

# %%
# Load the second CSV file into a DataFrame
la_crime_data_2020_to_2021 = pd.read_csv(os.path.join(path, files[1]))
la_crime_data_2020_to_2021
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 0        10304468  01/08/2020 12:00:00 AM  01/08/2020 12:00:00 AM      2230
# 1       190101086  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM       330
# 2       201220752  09/16/2020 12:00:00 AM  09/16/2020 12:00:00 AM      1230
# 3       191501505  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM      1730
# 4       191921269  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM       415
# ...           ...                     ...                     ...       ...
# 276579  210404776  01/21/2021 12:00:00 AM  01/19/2021 12:00:00 AM      1600
# 276580  212000771  05/28/2021 12:00:00 AM  05/28/2021 12:00:00 AM      1930
# 276581  211208872  03/19/2021 12:00:00 AM  03/19/2021 12:00:00 AM      1105
# 276582  210506531  03/04/2021 12:00:00 AM  03/04/2021 12:00:00 AM      2210
# 276583  212005847  02/22/2021 12:00:00 AM  02/22/2021 12:00:00 AM      1200
#
# ...

# %%
# Combine datasets
la_crime_data_2010_to_2020 = pd.concat([la_crime_data_2010_to_2019, la_crime_data_2020_to_2021], ignore_index=True)

# Convert 'Date Rptd' and 'DATE OCC' columns from string to datetime objects
la_crime_data_2010_to_2020['Date Rptd'] = pd.to_datetime(la_crime_data_2010_to_2020['Date Rptd'], format='%m/%d/%Y %I:%M:%S %p')
la_crime_data_2010_to_2020['DATE OCC'] = pd.to_datetime(la_crime_data_2010_to_2020['DATE OCC'], format='%m/%d/%Y %I:%M:%S %p')

# Filter out records from 2021
la_crime_data_2010_to_2020 = la_crime_data_2010_to_2020[la_crime_data_2010_to_2020['DATE OCC'].dt.year < 2021]

# Confirm the filtering
print(f"Filtered Data Range: {la_crime_data_2010_to_2020['DATE OCC'].min()} to {la_crime_data_2010_to_2020['DATE OCC'].max()}")
# Out:
# Filtered Data Range: 2010-01-01 00:00:00 to 2020-12-31 00:00:00

# %%
# Inspect column names
la_crime_data_2010_to_2020.columns.tolist()
# Out:
# ['DR_NO',
#  'Date Rptd',
#  'DATE OCC',
#  'TIME OCC',
#  'AREA ',
#  'AREA NAME',
#  'Rpt Dist No',
#  'Part 1-2',
#  'Crm Cd',
#  'Crm Cd Desc',
#  'Mocodes',
#  'Vict Age',
#  'Vict Sex',
#  'Vict Descent',
#  'Premis Cd',
#  'Premis Desc',
#  'Weapon Used Cd',
#  'Weapon Desc',
#  'Status',
#  'Status Desc',
#  'Crm Cd 1',
#  'Crm Cd 2',
#  'Crm Cd 3',
#  'Crm Cd 4',
#  'LOCATION',
#  'Cross Street',
#  'LAT',
#  'LON',
#  'AREA']

# %%
# Removed unnecessary spacing
la_crime_data_2010_to_2020.columns = la_crime_data_2010_to_2020.columns.str.strip()

# Dropped crime code columns 2, 3, 4
la_crime_data_2010_to_2020 = la_crime_data_2010_to_2020.drop(columns=['Crm Cd 2', 'Crm Cd 3', 'Crm Cd 4'])
la_crime_data_2010_to_2020
# Out:
#              DR_NO  Date Rptd   DATE OCC  TIME OCC  AREA    AREA NAME  \
# 0          1307355 2010-02-20 2010-02-20      1350  13.0       Newton
# 1         11401303 2010-09-13 2010-09-12        45  14.0      Pacific
# 2         70309629 2010-08-09 2010-08-09      1515  13.0       Newton
# 3         90631215 2010-01-05 2010-01-05       150   6.0    Hollywood
# 4        100100501 2010-01-03 2010-01-02      2100   1.0      Central
# ...            ...        ...        ...       ...   ...          ...
# 2386605  210610421 2021-05-30 2020-11-01      1200   NaN    Hollywood
# 2386606  210509668 2021-05-14 2020-11-01      1255   NaN       Harbor
# 2386607  200815985 2020-11-01 2020-11-01      1600   NaN      West LA
# 2386608  201518327 2020-12-04 2020-12-04      2045   NaN  N Hollywood
# 2386609  201401034 2020-11-23 2020-11-23      2100   NaN      Pacific
#
#          Rpt Dist No  Part 1-2  Crm Cd  \
# 0               1385         2     900
# 1               1485         2     740
# ...

# %%
# Remove duplicate rows from the DataFrame
la_crime_data_2010_to_2020 = la_crime_data_2010_to_2020.drop_duplicates()
la_crime_data_2010_to_2020
# Out:
#              DR_NO  Date Rptd   DATE OCC  TIME OCC  AREA    AREA NAME  \
# 0          1307355 2010-02-20 2010-02-20      1350  13.0       Newton
# 1         11401303 2010-09-13 2010-09-12        45  14.0      Pacific
# 2         70309629 2010-08-09 2010-08-09      1515  13.0       Newton
# 3         90631215 2010-01-05 2010-01-05       150   6.0    Hollywood
# 4        100100501 2010-01-03 2010-01-02      2100   1.0      Central
# ...            ...        ...        ...       ...   ...          ...
# 2386605  210610421 2021-05-30 2020-11-01      1200   NaN    Hollywood
# 2386606  210509668 2021-05-14 2020-11-01      1255   NaN       Harbor
# 2386607  200815985 2020-11-01 2020-11-01      1600   NaN      West LA
# 2386608  201518327 2020-12-04 2020-12-04      2045   NaN  N Hollywood
# 2386609  201401034 2020-11-23 2020-11-23      2100   NaN      Pacific
#
#          Rpt Dist No  Part 1-2  Crm Cd  \
# 0               1385         2     900
# 1               1485         2     740
# ...

# %%
# Fill NaNs with 0
la_crime_data_2010_to_2020.fillna(0)
# Out:
#              DR_NO  Date Rptd   DATE OCC  TIME OCC  AREA    AREA NAME  \
# 0          1307355 2010-02-20 2010-02-20      1350  13.0       Newton
# 1         11401303 2010-09-13 2010-09-12        45  14.0      Pacific
# 2         70309629 2010-08-09 2010-08-09      1515  13.0       Newton
# 3         90631215 2010-01-05 2010-01-05       150   6.0    Hollywood
# 4        100100501 2010-01-03 2010-01-02      2100   1.0      Central
# ...            ...        ...        ...       ...   ...          ...
# 2386605  210610421 2021-05-30 2020-11-01      1200   0.0    Hollywood
# 2386606  210509668 2021-05-14 2020-11-01      1255   0.0       Harbor
# 2386607  200815985 2020-11-01 2020-11-01      1600   0.0      West LA
# 2386608  201518327 2020-12-04 2020-12-04      2045   0.0  N Hollywood
# 2386609  201401034 2020-11-23 2020-11-23      2100   0.0      Pacific
#
#          Rpt Dist No  Part 1-2  Crm Cd  \
# 0               1385         2     900
# 1               1485         2     740
# ...

# %%
# Check the data types of each column
print(la_crime_data_2010_to_2020.dtypes)
# Out:
# DR_NO                      int64
# Date Rptd         datetime64[ns]
# DATE OCC          datetime64[ns]
# TIME OCC                   int64
# AREA                     float64
# AREA NAME                 object
# Rpt Dist No                int64
# Part 1-2                   int64
# Crm Cd                     int64
# Crm Cd Desc               object
# Mocodes                   object
# Vict Age                   int64
# Vict Sex                  object
# Vict Descent              object
# Premis Cd                float64
# Premis Desc               object
# Weapon Used Cd           float64
# Weapon Desc               object
# Status                    object
# Status Desc               object
# Crm Cd 1                 float64
# LOCATION                  object
# Cross Street              object
# LAT                      float64
# LON                      float64
# AREA                     float64
# dtype: object

# %%
# Convert LAT and LON columns to geometry tuples
la_crime_data_2010_to_2020['Geometry'] = la_crime_data_2010_to_2020.apply(
    lambda row: (row['LON'], row['LAT']), axis=1
)
# Move the geometry column to be right after longitude
lon_index = la_crime_data_2010_to_2020.columns.get_loc('LON')
la_crime_data_2010_to_2020.insert(lon_index + 1, 'Geometry', la_crime_data_2010_to_2020.pop('Geometry'))
la_crime_data_2010_to_2020
# Out:
#              DR_NO  Date Rptd   DATE OCC  TIME OCC  AREA    AREA NAME  \
# 0          1307355 2010-02-20 2010-02-20      1350  13.0       Newton
# 1         11401303 2010-09-13 2010-09-12        45  14.0      Pacific
# 2         70309629 2010-08-09 2010-08-09      1515  13.0       Newton
# 3         90631215 2010-01-05 2010-01-05       150   6.0    Hollywood
# 4        100100501 2010-01-03 2010-01-02      2100   1.0      Central
# ...            ...        ...        ...       ...   ...          ...
# 2386605  210610421 2021-05-30 2020-11-01      1200   NaN    Hollywood
# 2386606  210509668 2021-05-14 2020-11-01      1255   NaN       Harbor
# 2386607  200815985 2020-11-01 2020-11-01      1600   NaN      West LA
# 2386608  201518327 2020-12-04 2020-12-04      2045   NaN  N Hollywood
# 2386609  201401034 2020-11-23 2020-11-23      2100   NaN      Pacific
#
#          Rpt Dist No  Part 1-2  Crm Cd  \
# 0               1385         2     900
# 1               1485         2     740
# ...

# %%
la_crime_data_2010_to_2020
# Out:
#              DR_NO  Date Rptd   DATE OCC  TIME OCC  AREA    AREA NAME  \
# 0          1307355 2010-02-20 2010-02-20      1350  13.0       Newton
# 1         11401303 2010-09-13 2010-09-12        45  14.0      Pacific
# 2         70309629 2010-08-09 2010-08-09      1515  13.0       Newton
# 3         90631215 2010-01-05 2010-01-05       150   6.0    Hollywood
# 4        100100501 2010-01-03 2010-01-02      2100   1.0      Central
# ...            ...        ...        ...       ...   ...          ...
# 2386605  210610421 2021-05-30 2020-11-01      1200   NaN    Hollywood
# 2386606  210509668 2021-05-14 2020-11-01      1255   NaN       Harbor
# 2386607  200815985 2020-11-01 2020-11-01      1600   NaN      West LA
# 2386608  201518327 2020-12-04 2020-12-04      2045   NaN  N Hollywood
# 2386609  201401034 2020-11-23 2020-11-23      2100   NaN      Pacific
#
#          Rpt Dist No  Part 1-2  Crm Cd  \
# 0               1385         2     900
# 1               1485         2     740
# ...

# %%
print(la_crime_data_2010_to_2020.dtypes)
# Out:
# DR_NO                      int64
# Date Rptd         datetime64[ns]
# DATE OCC          datetime64[ns]
# TIME OCC                   int64
# AREA                     float64
# AREA NAME                 object
# Rpt Dist No                int64
# Part 1-2                   int64
# Crm Cd                     int64
# Crm Cd Desc               object
# Mocodes                   object
# Vict Age                   int64
# Vict Sex                  object
# Vict Descent              object
# Premis Cd                float64
# Premis Desc               object
# Weapon Used Cd           float64
# Weapon Desc               object
# Status                    object
# Status Desc               object
# Crm Cd 1                 float64
# LOCATION                  object
# Cross Street              object
# LAT                      float64
# LON                      float64
# Geometry                  object
# AREA                     float64
# dtype: object

# %%
# Calculate monthly crime counts by grouping the data based on 'Date OCC' and returns the count of each group.
monthly_counts = la_crime_data_2010_to_2020.set_index('DATE OCC').resample('ME').size().reset_index(name='Count')
monthly_counts
# Out:
#       DATE OCC  Count
# 0   2010-01-31  19457
# 1   2010-02-28  16020
# 2   2010-03-31  18128
# 3   2010-04-30  17770
# 4   2010-05-31  17716
# ..         ...    ...
# 127 2020-08-31  16651
# 128 2020-09-30  15448
# 129 2020-10-31  16252
# 130 2020-11-30  15298
# 131 2020-12-31  15657
#
# [132 rows x 2 columns]

# %%
# Sort the DataFrame based on 'DATE OCC'
la_crime_data_2010_to_2020_sorted = la_crime_data_2010_to_2020.sort_values(by='DATE OCC')
la_crime_data_2010_to_2020_sorted
# Out:
#              DR_NO  Date Rptd   DATE OCC  TIME OCC  AREA    AREA NAME  \
# 204472   111619978 2011-12-07 2010-01-01      1800  16.0     Foothill
# 192707   102107774 2010-03-10 2010-01-01       800  21.0      Topanga
# 206708   121806980 2012-02-29 2010-01-01         1  18.0    Southeast
# 206716   121810013 2012-04-25 2010-01-01       800  18.0    Southeast
# 206718   121810790 2012-05-10 2010-01-01      1200  18.0    Southeast
# ...            ...        ...        ...       ...   ...          ...
# 2321869  200300960 2020-12-31 2020-12-31      1245   NaN    Southwest
# 2353127  211204080 2021-01-01 2020-12-31      1430   NaN  77th Street
# 2321877  202018991 2020-12-31 2020-12-31      1315   NaN      Olympic
# 2321885  210604220 2021-01-07 2020-12-31      2130   NaN    Hollywood
# 2320006  211704853 2021-01-23 2020-12-31      1700   NaN   Devonshire
#
#          Rpt Dist No  Part 1-2  Crm Cd  \
# 204472          1685         2     812
# 192707          2104         2     740
# ...

# %%
# Sort the DataFrame based on 'DATE OCC'
la_crime_data_2010_to_2020_sorted = la_crime_data_2010_to_2020.sort_values(by='DATE OCC')

# Save the sorted DataFrame to a CSV file
la_crime_data_2010_to_2020_sorted.to_csv(r'C:\Users\odiss\OneDrive\Desktop\la_crime_data_sorted.csv', index=False)

# %%
plt.figure(figsize=(10, 6))
plt.plot(monthly_counts['DATE OCC'], monthly_counts['Count'], marker='o', linestyle='-')
plt.title('Monthly Crime Counts')
plt.xlabel('Date')
plt.ylabel('Number of Crimes')
plt.grid(True)
plt.xticks(rotation=45)  # Rotate the date labels for better readability
plt.tight_layout()  # Adjust layout to make room for the rotated date labels
plt.show()

# %%
# Filter for theft, burglary, and robbery crimes
tbr_crimes = la_crime_data_2010_to_2020_sorted[
    la_crime_data_2010_to_2020_sorted['Crm Cd Desc'].str.contains('THEFT|BURGLARY|ROBBERY', case=False, na=False)
]

# Count the monthly occurrences
monthly_counts_tbr = tbr_crimes.resample('ME', on='DATE OCC').size().reset_index(name='Count')

# Plot
plt.figure(figsize=(12, 8))
plt.plot(monthly_counts['DATE OCC'], monthly_counts['Count'], marker='o', label='All Crimes', linestyle='-')
plt.plot(monthly_counts_tbr['DATE OCC'], monthly_counts_tbr['Count'], marker='s', label='Theft, Burglary, and Robbery', linestyle='--')

# Chart formatting
plt.title('Monthly Crime Counts: All Crimes vs. Theft, Burglary, and Robbery')
plt.xlabel('Date')
plt.ylabel('Number of Crimes')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)  # Rotate the date labels for better readability
plt.tight_layout()  # Adjust layout to make room for the rotated date labels
plt.show()

# %%
# Ensure the date columns are datetime type
la_crime_data_2010_to_2020_sorted['DATE OCC'] = pd.to_datetime(la_crime_data_2010_to_2020_sorted['DATE OCC'])

# Extract day of the week
la_crime_data_2010_to_2020_sorted['Day of Week'] = la_crime_data_2010_to_2020_sorted['DATE OCC'].dt.day_name()

# Aggregate total crime counts by day of the week
total_crimes = la_crime_data_2010_to_2020_sorted.groupby('Day of Week').size().reindex(
    ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
).reset_index(name='Total Crimes')

# Analyzing specific crime patterns for thefts
theft_data = la_crime_data_2010_to_2020_sorted[la_crime_data_2010_to_2020_sorted['Crm Cd Desc'].str.contains('THEFT', case=False)]
theft_counts = theft_data.groupby('Day of Week').size().reindex(
    ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
).reset_index(name='Thefts')

# Analyzing specific crime patterns for assaults
assault_data = la_crime_data_2010_to_2020_sorted[la_crime_data_2010_to_2020_sorted['Crm Cd Desc'].str.contains('ASSAULT', na=False)]
assault_counts = assault_data.groupby('Day of Week').size().reindex(
    ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
).reset_index(name='Assaults')

# Merge the dataframes
weekly_data = pd.merge(total_crimes, theft_counts, on='Day of Week')
weekly_data = pd.merge(weekly_data, assault_counts, on='Day of Week')

# Plotting the weekly distribution of all crimes, thefts, and assaults
plt.figure(figsize=(14, 7))
bar_width = 0.25
r1 = range(len(weekly_data['Day of Week']))
r2 = [x + bar_width for x in r1]
r3 = [x + bar_width for x in r2]

plt.bar(r1, weekly_data['Total Crimes'], color='#0077b6', width=bar_width, label='Total Crimes')
plt.bar(r2, weekly_data['Thefts'], color='#0096c7', width=bar_width, label='Thefts')
plt.bar(r3, weekly_data['Assaults'], color='#48cae4', width=bar_width, label='Assaults')

plt.xlabel('Day of Week', fontweight='bold')
plt.ylabel('Number of Incidents', fontweight='bold')
plt.title('Weekly Distribution of Crimes, Thefts, and Assaults')
plt.xticks([r + bar_width for r in range(len(weekly_data['Day of Week']))], weekly_data['Day of Week'])
plt.legend()

plt.show()

# Convert 'TIME OCC' to hour of the day
la_crime_data_2010_to_2020_sorted['Hour'] = la_crime_data_2010_to_2020_sorted['TIME OCC'] // 100

# Group by hour for total crimes, thefts, and assaults
hourly_total = la_crime_data_2010_to_2020_sorted.groupby('Hour').size()
hourly_thefts = la_crime_data_2010_to_2020_sorted[la_crime_data_2010_to_2020_sorted['Crm Cd Desc'].str.contains('THEFT', case=False)].groupby('Hour').size()
hourly_assaults = la_crime_data_2010_to_2020_sorted[la_crime_data_2010_to_2020_sorted['Crm Cd Desc'].str.contains('ASSAULT', case=False)].groupby('Hour').size()

# Create a DataFrame to hold the values
hourly_distribution = pd.DataFrame({
    'Total Crimes': hourly_total,
    'Thefts': hourly_thefts,
    'Assaults': hourly_assaults
})

# Plotting
plt.figure(figsize=(14, 7))
for column in hourly_distribution.columns:
    plt.plot(hourly_distribution.index, hourly_distribution[column], label=column)

plt.title('Hourly Distribution of Total Crimes, Thefts, and Assaults')
plt.xlabel('Hour of Day')
plt.ylabel('Number of Crimes')
plt.legend(title='Type of Crime')  # Custom legend title
plt.grid(True)
plt.xticks(range(0, 24))  # Ensure all hours are shown
plt.tight_layout()
plt.show()

# %%
fig = px.line(monthly_counts, x='DATE OCC', y='Count', title='Monthly Crime Counts',
              labels={'DATE OCC': 'Date', 'Count': 'Number of Crimes'},
              markers=True)

# Update layout to enhance readability
fig.update_layout(xaxis_title='Date',
                  yaxis_title='Number of Crimes',
                  xaxis_tickangle=-45)

fig.show()

# %%
# Define age groups
def categorize_age(age):
    if age < 18:
        return 'Under 18'
    elif 18 <= age < 30:
        return '18-29'
    elif 30 <= age < 50:
        return '30-49'
    elif 50 <= age < 65:
        return '50-64'
    else:
        return '65+'

# Categorize age if not already done
if 'Age Group' not in la_crime_data_2010_to_2020_sorted.columns:
    la_crime_data_2010_to_2020_sorted['Age Group'] = la_crime_data_2010_to_2020_sorted['Vict Age'].apply(categorize_age)

# Count crimes by age group
age_group_counts = la_crime_data_2010_to_2020_sorted['Age Group'].value_counts()

# Plotting a pie chart for age groups involved in crimes
plt.figure(figsize=(10, 8))
age_group_counts.plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=plt.cm.Paired(range(len(age_group_counts))))
plt.title('Distribution of Crimes by Age Group')
plt.ylabel('')  # Hide y-axis label for cleanliness
plt.show()

# %%
# Convert 'TIME OCC' to hour of the day
la_crime_data_2010_to_2020_sorted['Hour'] = la_crime_data_2010_to_2020_sorted['TIME OCC'] // 100

# Group by hour and age group
hourly_crimes_by_age = la_crime_data_2010_to_2020_sorted.groupby(['Hour', 'Age Group']).size().unstack(fill_value=0)

# Adding a total crimes per hour line
hourly_crimes_by_age['Total'] = hourly_crimes_by_age.sum(axis=1)

# Reorder columns so "Under 18" is first
columns_order = ['Under 18'] + [col for col in hourly_crimes_by_age.columns if col != 'Under 18']
hourly_crimes_by_age = hourly_crimes_by_age[columns_order]

# Plotting crimes per hour, colored by age groups and including total
plt.figure(figsize=(14, 7))
for column in hourly_crimes_by_age.columns:
    plt.plot(hourly_crimes_by_age.index, hourly_crimes_by_age[column], label=column)

plt.title('Crimes Per Hour by Age Group and Total')
plt.xlabel('Hour of Day')
plt.ylabel('Number of Crimes')
plt.legend(title='Age Group / Total')  # Keep the original legend location
plt.grid(True)
plt.xticks(range(0, 24))  # Ensure all hours are shown
plt.tight_layout()
plt.show()

# %%
# Group by 'Age Group' and 'Crm Cd Desc', then count occurrences
crime_counts = la_crime_data_2010_to_2020_sorted.groupby(['Age Group', 'Crm Cd Desc'], observed=True).size()

# Sort within each age group and select the top 5 crimes
top_crimes_by_group = (
    crime_counts.groupby(level=0, group_keys=False, observed=True)
    .nlargest(5)
    .reset_index(name='Count')
)

# Pivot the table so that age groups are columns and ranks are rows
ranked_table = (
    top_crimes_by_group.assign(Rank=top_crimes_by_group.groupby('Age Group').cumcount() + 1)
    .pivot(index='Rank', columns='Age Group', values='Crm Cd Desc')
)

# Display the table
print("Top 5 Crimes by Age Group (Transposed Table):")
print(ranked_table)


file_path = "Top_5_Crimes_by_Age_Group.csv"
ranked_table.to_csv(file_path)
# Out:
# Top 5 Crimes by Age Group (Transposed Table):
# Age Group                                           18-29  \
# Rank
# 1                                BATTERY - SIMPLE ASSAULT
# 2                                   BURGLARY FROM VEHICLE
# 3                       INTIMATE PARTNER - SIMPLE ASSAULT
# 4                      THEFT PLAIN - PETTY ($950 & UNDER)
# 5          ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
#
# Age Group                              30-49  \
# Rank
# 1                      BURGLARY FROM VEHICLE
# 2                   BATTERY - SIMPLE ASSAULT
# 3                                   BURGLARY
# 4          INTIMATE PARTNER - SIMPLE ASSAULT
# 5                          THEFT OF IDENTITY
#
# Age Group                               50-64  \
# Rank
# 1                    BATTERY - SIMPLE ASSAULT
# 2                                    BURGLARY
# 3                           THEFT OF IDENTITY
# 4          THEFT PLAIN - PETTY ($950 & UNDER)
# ...

# %%
# Mapping descent codes to full descriptions
descent_mapping = {
    'A': 'Other Asian', 'B': 'Black', 'C': 'Chinese', 'D': 'Cambodian',
    'F': 'Filipino', 'G': 'Guamanian', 'H': 'Hispanic/Latin/Mexican',
    'I': 'American Indian/Alaskan Native', 'J': 'Japanese', 'K': 'Korean',
    'L': 'Laotian', 'O': 'Other', 'P': 'Pacific Islander', 'S': 'Samoan',
    'U': 'Hawaiian', 'V': 'Vietnamese', 'W': 'White', 'X': 'Unknown',
    'Z': 'Asian Indian'
}

# Assuming 'la_crime_data_2010_to_2020_sorted' is your DataFrame
la_crime_data_2010_to_2020_sorted['Date Rptd'] = pd.to_datetime(la_crime_data_2010_to_2020_sorted['Date Rptd'])
la_crime_data_2010_to_2020_sorted['DATE OCC'] = pd.to_datetime(la_crime_data_2010_to_2020_sorted['DATE OCC'])
la_crime_data_2010_to_2020_sorted['Report Delay'] = (la_crime_data_2010_to_2020_sorted['Date Rptd'] - la_crime_data_2010_to_2020_sorted['DATE OCC']).dt.days

# Filter and group by 'Vict Descent'
valid_descents = ['A', 'B', 'C', 'D', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'O', 'P', 'S', 'U', 'V', 'W', 'X', 'Z']
filtered_data = la_crime_data_2010_to_2020_sorted[la_crime_data_2010_to_2020_sorted['Vict Descent'].isin(valid_descents)]
stats_by_descent = filtered_data.groupby('Vict Descent').agg({
    'Report Delay': 'mean',
    'Crm Cd': 'mean'
}).reset_index()

# Normalize Crime Seriousness and sort by Report Delay
stats_by_descent['Normalized Crime Seriousness'] = (stats_by_descent['Crm Cd'] - stats_by_descent['Crm Cd'].min()) / (stats_by_descent['Crm Cd'].max() - stats_by_descent['Crm Cd'].min())
stats_by_descent.sort_values('Report Delay', ascending=False, inplace=True)
stats_by_descent['Descent Description'] = stats_by_descent['Vict Descent'].map(descent_mapping)

# Visualization
fig, ax = plt.subplots(figsize=(14, 8))
colors = [plt.cm.Reds(x) for x in stats_by_descent['Normalized Crime Seriousness']]
bars = ax.bar(stats_by_descent['Descent Description'], stats_by_descent['Report Delay'], color=colors)
ax.set_xlabel('Victim Descent')
ax.set_ylabel('Average Report Delay (days)')
ax.set_title('Average Reporting Delay by Victim Descent with Crime Seriousness')
cbar = fig.colorbar(plt.cm.ScalarMappable(norm=plt.Normalize(vmin=0, vmax=1), cmap='Reds'), ax=ax, label='Crime Seriousness (Normalized)')

# Set x-ticks and align text
ax.set_xticklabels(stats_by_descent['Descent Description'], rotation=45, ha='right', rotation_mode='anchor')

plt.show()
# Out:
# C:\Users\odiss\AppData\Local\Temp\ipykernel_44020\2701464219.py:39: UserWarning:
#
# set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.

# %%
# Mapping descent codes to full descriptions
descent_mapping = {
    'A': 'Other Asian', 'B': 'Black', 'C': 'Chinese', 'D': 'Cambodian',
    'F': 'Filipino', 'G': 'Guamanian', 'H': 'Hispanic/Latin/Mexican',
    'I': 'American Indian/Alaskan Native', 'J': 'Japanese', 'K': 'Korean',
    'L': 'Laotian', 'O': 'Other', 'P': 'Pacific Islander', 'S': 'Samoan',
    'U': 'Hawaiian', 'V': 'Vietnamese', 'W': 'White', 'X': 'Unknown',
    'Z': 'Asian Indian'
}

# Calculate the total cases by victim descent
cases_by_descent = la_crime_data_2010_to_2020_sorted['Vict Descent'].value_counts()

# Apply descent mapping to index
cases_by_descent.index = [descent_mapping.get(idx, idx) for idx in cases_by_descent.index]

# Group smaller slices into "All Other Categories" for better readability
threshold = 0.05  # Group categories smaller than 5% of total
total_cases = cases_by_descent.sum()
large_slices = cases_by_descent[cases_by_descent / total_cases > threshold]
small_slices = cases_by_descent[cases_by_descent / total_cases <= threshold]
if not small_slices.empty:
    large_slices['All Other Categories'] = small_slices.sum()

# Simplified pie chart
plt.figure(figsize=(10, 8))
plt.pie(
    large_slices,
    labels=large_slices.index,
    autopct='%1.1f%%',
    startangle=90,
    colors=plt.cm.tab20.colors
)
plt.title('Total Crime Cases by Victim Descent')
plt.tight_layout()
plt.show()

# %%
# Ensure 'DATE OCC' and 'Vict Sex' are appropriately formatted
la_crime_data_2010_to_2020_sorted['DATE OCC'] = pd.to_datetime(la_crime_data_2010_to_2020_sorted['DATE OCC'])

# Filter for relevant genders
relevant_genders = la_crime_data_2010_to_2020_sorted['Vict Sex'].isin(['M', 'F', 'X'])
filtered_data = la_crime_data_2010_to_2020_sorted[relevant_genders]

# Group by month and victim's gender
monthly_crimes_by_gender = filtered_data.groupby([pd.Grouper(key='DATE OCC', freq='ME'), 'Vict Sex']).size().unstack(fill_value=0)

# Plotting
plt.figure(figsize=(14, 7))
gender_labels = {'M': 'Males', 'F': 'Females', 'X': 'Non-Binary/Unknown'}
for gender in ['M', 'F', 'X']:  # Specifically plot only these categories
    if gender in monthly_crimes_by_gender.columns:
        plt.plot(monthly_crimes_by_gender.index, monthly_crimes_by_gender[gender], label=f'Crimes - {gender_labels[gender]}')

plt.title('Monthly Crime Frequency by Gender')
plt.xlabel('Month')
plt.ylabel('Number of Crimes')
plt.legend()
plt.show()

# %%
from matplotlib.colors import LinearSegmentedColormap
from matplotlib.cm import ScalarMappable

# Considering all crimes, not just those involving firearms
all_crimes = la_crime_data_2010_to_2020_sorted.copy()

# Filtering for defined genders 'M', 'F', 'X' (adjust as necessary)
valid_genders = ['M', 'F', 'X']
filtered_data = all_crimes[all_crimes['Vict Sex'].isin(valid_genders)]

# Grouping data by gender and calculating average crime code for normalization
stats_by_gender = filtered_data.groupby('Vict Sex').agg({
    'Crm Cd': 'mean'  # Calculate the average crime code (severity of crime)
}).reset_index()

# Normalizing the severity
stats_by_gender['Normalized Crime Seriousness'] = (stats_by_gender['Crm Cd'] - stats_by_gender['Crm Cd'].min()) / (stats_by_gender['Crm Cd'].max() - stats_by_gender['Crm Cd'].min())

# Mapping the normalized values to the respective genders for the pie chart
normalized_severity = stats_by_gender.set_index('Vict Sex')['Normalized Crime Seriousness']

# Create a colormap from light red to dark red
cmap = LinearSegmentedColormap.from_list("severity", ["#ffcccc", "#ff0000"])
norm = plt.Normalize(min(normalized_severity), max(normalized_severity))

# Creating the pie chart
fig, ax = plt.subplots()
colors = [cmap(norm(value)) for value in normalized_severity]
wedges, texts, autotexts = ax.pie(filtered_data['Vict Sex'].value_counts(), labels=filtered_data['Vict Sex'].value_counts().index, autopct='%1.1f%%', startangle=90, colors=colors)

# Add a colorbar for visual reference of severity
sm = ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])
cbar = fig.colorbar(sm, ax=ax, orientation='vertical')
cbar.set_label('Normalized Crime Seriousness')

# Equal aspect ratio ensures that pie is drawn as a circle
ax.axis('equal')

# Title and visual layout adjustments
plt.title('Percentage of Crime Incidents by Victim Gender with Severity Indicator')
plt.tight_layout()
plt.show()

# %%
# Define the classification function to categorize crimes based on severity and gender
def classify_crime_by_gender(row):
    gender = str(row['Vict Sex']).upper()
    if gender not in ['M', 'F', 'X']:  # Including 'X' for non-binary or unspecified genders
        return None
    
    crm_cd_desc = str(row['Crm Cd Desc']).upper()
    # Keywords to categorize crimes more specifically by their severity
    if any(word in crm_cd_desc for word in ['FELONY', 'AGGRAVATED', 'MAJOR']):
        return f'{gender} - Felony'
    elif any(word in crm_cd_desc for word in ['MISDEMEANOR', 'PETTY', 'MINOR', 'LESSER']):
        return f'{gender} - Misdemeanor'
    else:
        return f'{gender} - Other'

# Apply the classification
la_crime_data_2010_to_2020_sorted['Crime Classification'] = la_crime_data_2010_to_2020_sorted.apply(classify_crime_by_gender, axis=1)

# Count the crimes in each category for males, females, and non-binary/other
crime_counts = la_crime_data_2010_to_2020_sorted['Crime Classification'].value_counts()

# Prepare data for plotting
categories = ['Felony', 'Misdemeanor', 'Other']
male_crimes = [crime_counts.get(f'M - {cat}', 0) for cat in categories]
female_crimes = [crime_counts.get(f'F - {cat}', 0) for cat in categories]
nonbinary_crimes = [crime_counts.get(f'X - {cat}', 0) for cat in categories]

# Plotting the results
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(18, 6), sharey=True)
axes[0].bar(categories, male_crimes, color=['red', 'yellow', 'gray'])
axes[0].set_title('Male Victim Crimes')
axes[1].bar(categories, female_crimes, color=['blue', 'lightblue', 'grey'])
axes[1].set_title('Female Victim Crimes')
axes[2].bar(categories, nonbinary_crimes, color=['green', 'lightgreen', 'lightgrey'])
axes[2].set_title('Non-Binary/Other Victim Crimes')

plt.tight_layout()
plt.show()

# %%
# Filter for gun-related crimes
gun_crimes = la_crime_data_2010_to_2020_sorted[
    la_crime_data_2010_to_2020_sorted['Weapon Desc'].str.contains('GUN|FIREARM|RIFLE|PISTOL', na=True, case=False)
]

# Filter for non-gun violent crimes
violent_crimes = la_crime_data_2010_to_2020_sorted[
    la_crime_data_2010_to_2020_sorted['Crm Cd Desc'].str.contains('ASSAULT|ROBBERY|HOMICIDE', na=True, case=False)
]
non_gun_violent_crimes = violent_crimes[
    ~violent_crimes['Weapon Desc'].str.contains('GUN|FIREARM|RIFLE|PISTOL', na=True, case=False)
]

# Average severity for gun and non-gun crimes
average_severity_gun = gun_crimes['Crm Cd'].mean()
average_severity_non_gun = non_gun_violent_crimes['Crm Cd'].mean()

print(f"Average Crime Code for Gun-Related Crimes: {average_severity_gun}")
print(f"Average Crime Code for Non-Gun Violent Crimes: {average_severity_non_gun}")

# Group by month to get counts
gun_crimes_monthly = gun_crimes.resample('ME', on='DATE OCC').size()
non_gun_violent_crimes_monthly = non_gun_violent_crimes.resample('ME', on='DATE OCC').size()

# Plotting
plt.figure(figsize=(14, 7))
gun_crimes_monthly.plot(label='Gun-Related Crimes')
non_gun_violent_crimes_monthly.plot(label='Non-Gun Violent Crimes')
plt.title('Monthly Crime Frequency')
plt.xlabel('Month')
plt.ylabel('Number of Crimes')
plt.legend()
plt.show()
# Out:
# Average Crime Code for Gun-Related Crimes: 491.88932815930394
# Average Crime Code for Non-Gun Violent Crimes: 486.9942542359708

# %%
# Filter columns for gun-related crimes
gun_related_crimes = la_crime_data_2010_to_2020_sorted[
    la_crime_data_2010_to_2020_sorted['Weapon Desc'].str.contains("GUN", na=False)
]

# Analyze the types of guns used
guns_used_counts = gun_related_crimes['Weapon Desc'].value_counts()

# Calculate percentage of each gun type
total_gun_crimes = guns_used_counts.sum()
gun_percentages = (guns_used_counts / total_gun_crimes) * 100

# Consolidate categories smaller than 2.5% into "Other"
guns_used_counts = guns_used_counts[gun_percentages >= 2.5]
guns_used_counts["Other"] = total_gun_crimes - guns_used_counts.sum()

# Create a pie chart showing the percentage of different guns used
plt.figure(figsize=(10, 8))
guns_used_counts.plot.pie(
    autopct='%1.1f%%',
    startangle=90,
    labels=guns_used_counts.index,
    title="Percentage of Different Guns Used in Crimes"
)
plt.ylabel("")  # Remove the default y-axis label
plt.show()

# %%
# Group and count crimes by 'Premis Desc' and 'Crm Cd Desc'
crime_counts = la_crime_data_2010_to_2020_sorted.groupby(['Premis Desc', 'Crm Cd Desc']).size().unstack(fill_value=0)

# Calculate the total crimes for each premise to find the most crime-prone premises
crime_counts['Total'] = crime_counts.sum(axis=1)

# Select the top 10 most crime-prone premises
top_premises = crime_counts.sort_values(by='Total', ascending=False).head(10)

# Drop the 'Total' column before extracting top crimes
top_premises = top_premises.drop(columns='Total')

# Get the top 10 crimes overall to focus on
top_crimes = la_crime_data_2010_to_2020_sorted['Crm Cd Desc'].value_counts().head(10).index

# Filter the top premises for these top crimes only
top_premises = top_premises[top_crimes]

# Plotting using a heatmap
plt.figure(figsize=(14, 10))
sns.heatmap(top_premises, annot=True, fmt="g", cmap='coolwarm', linewidths=.5)
plt.title('Heatmap of Crime Distribution Across Top 10 Premises and Crimes')
plt.xlabel('Crime Type')
plt.ylabel('Premise Type')
plt.xticks(rotation=45, ha='right')  # Slant x-axis labels
plt.tight_layout()  # Adjust layout to make room for label text

plt.show()
