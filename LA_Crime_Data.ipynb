# %%
# !pip install kagglehub

# !pip install kaggle
# Out:
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: C:\Users\odiss\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for kaggle: filename=kaggle-1.6.17-py3-none-any.whl size=105797 sha256=a3edef6442b491a577fdfc6fc3439a7ab57eb8dd9ab4a468691a23a7096be49d
#   Stored in directory: c:\users\odiss\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local\pip\cache\wheels\ff\55\fb\b27a466be754d2a06ffe0e37b248d844f090a63b51becea85d
# Successfully built kaggle
# ...

# %%
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.6 MB 8.5 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.6/11.6 MB 4.2 MB/s eta 0:00:03
#    ------- -------------------------------- 2.1/11.6 MB 4.1 MB/s eta 0:00:03
#    --------- ------------------------------ 2.9/11.6 MB 3.7 MB/s eta 0:00:03
#    ------------ --------------------------- 3.7/11.6 MB 4.0 MB/s eta 0:00:03
#    ----------------- ---------------------- 5.0/11.6 MB 4.1 MB/s eta 0:00:02
#    ------------------ --------------------- 5.5/11.6 MB 3.9 MB/s eta 0:00:02
#    ----------------------- ---------------- 6.8/11.6 MB 4.2 MB/s eta 0:00:02
#    -------------------------- ------------- 7.6/11.6 MB 4.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.4/11.6 MB 4.0 MB/s eta 0:00:01
#    ------------------------------- -------- 9.2/11.6 MB 4.1 MB/s eta 0:00:01
# ...

# %%
import kagglehub
import os
import pandas as pd

# Download latest version
path = kagglehub.dataset_download("sumaiaparveenshupti/los-angeles-crime-data-20102020")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\odiss\.cache\kagglehub\datasets\sumaiaparveenshupti\los-angeles-crime-data-20102020\versions\3

# %%
files = [f for f in os.listdir(path) if os.path.isfile(os.path.join(path, f))]

print("Files in directory:", files)
# Out:
# Files in directory: ['Crime_Data_from_2010_to_2019.csv', 'Crime_Data_from_2020_to_Present.csv']

# %%
df_0 = pd.read_csv(os.path.join(path, files[0]))
df_0
# Out:
#              DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 0          1307355  02/20/2010 12:00:00 AM  02/20/2010 12:00:00 AM      1350
# 1         11401303  09/13/2010 12:00:00 AM  09/12/2010 12:00:00 AM        45
# 2         70309629  08/09/2010 12:00:00 AM  08/09/2010 12:00:00 AM      1515
# 3         90631215  01/05/2010 12:00:00 AM  01/05/2010 12:00:00 AM       150
# 4        100100501  01/03/2010 12:00:00 AM  01/02/2010 12:00:00 AM      2100
# ...            ...                     ...                     ...       ...
# 2117584  190608903  03/28/2019 12:00:00 AM  03/28/2019 12:00:00 AM       400
# 2117585  190715222  08/15/2019 12:00:00 AM  08/14/2019 12:00:00 AM      1810
# 2117586  192004409  01/06/2019 12:00:00 AM  01/06/2019 12:00:00 AM      2100
# 2117587  191716777  10/17/2019 12:00:00 AM  10/16/2019 12:00:00 AM      1800
# 2117588  190805435  02/01/2019 12:00:00 AM  02/01/2019 12:00:00 AM      1615
#
# ...

# %%
df_1 = pd.read_csv(os.path.join(path, files[1]))
df_1
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 0        10304468  01/08/2020 12:00:00 AM  01/08/2020 12:00:00 AM      2230
# 1       190101086  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM       330
# 2       201220752  09/16/2020 12:00:00 AM  09/16/2020 12:00:00 AM      1230
# 3       191501505  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM      1730
# 4       191921269  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM       415
# ...           ...                     ...                     ...       ...
# 276579  210404776  01/21/2021 12:00:00 AM  01/19/2021 12:00:00 AM      1600
# 276580  212000771  05/28/2021 12:00:00 AM  05/28/2021 12:00:00 AM      1930
# 276581  211208872  03/19/2021 12:00:00 AM  03/19/2021 12:00:00 AM      1105
# 276582  210506531  03/04/2021 12:00:00 AM  03/04/2021 12:00:00 AM      2210
# 276583  212005847  02/22/2021 12:00:00 AM  02/22/2021 12:00:00 AM      1200
#
# ...

# %%
df_1[(df_1['AREA NAME']=='Harbor') | (df_1['AREA NAME']=='Hollywood')]
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 17      200506268  02/22/2020 12:00:00 AM  02/22/2020 12:00:00 AM      1900
# 41      200608399  03/28/2020 12:00:00 AM  03/27/2020 12:00:00 AM      1700
# 50      200611450  06/16/2020 12:00:00 AM  06/15/2020 12:00:00 AM      1800
# 132     200610699  05/27/2020 12:00:00 AM  05/24/2020 12:00:00 AM      1730
# 160     200608304  03/24/2020 12:00:00 AM  03/24/2020 12:00:00 AM      1550
# ...           ...                     ...                     ...       ...
# 276522  210607188  03/18/2021 12:00:00 AM  01/24/2021 12:00:00 AM      1000
# 276524  210504649  01/17/2021 12:00:00 AM  01/17/2021 12:00:00 AM       900
# 276562  210500569  03/02/2021 12:00:00 AM  03/02/2021 12:00:00 AM      2053
# 276574  210610209  05/25/2021 12:00:00 AM  05/25/2021 12:00:00 AM       813
# 276582  210506531  03/04/2021 12:00:00 AM  03/04/2021 12:00:00 AM      2210
#
# ...
